# %% [markdown]
# # 1. Efficient finetuning using LoRA - with litGPT

# %%
from IPython.display import Image
Image('fig/litgpt LLM load.png')

# %% [markdown]
# Takes too much time. 20% after 10 minutes since launch on a M4 Macbook pro.
